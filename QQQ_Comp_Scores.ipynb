# %%
import requests 
import pandas as pd
import numpy as np

# %%
# Performance is v141

headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'}
   
def get_screener(page):
    screen = requests.get(f'https://finviz.com/screener.ashx?v=141&f=exch_nasd&t=AAPL,ADBE,ADI,ADP,ADSK,AEP,ALGN,AMAT,AMD,AMGN,AMZN,ANSS,ASML,ATVI,AVGO,BIDU,BIIB,BKNG,CDNS,CDW,CERN,CHKP,CHTR,CMCSA,COST,CPRT,CSCO,CSX,CTAS,CTSH,DLTR,DOCU,DXCM,EA,EBAY,EXC,FAST,FB,FISV,FOX,FOXA,GILD,GOOG,GOOGL,HON,IDXX,ILMN,INCY,INTC,INTU,ISRG,JD,KDP,KHC,KLAC,LRCX,LULU,MAR,MCHP,MDLZ,MELI,MNST,MRNA,MRVL,MSFT,MTCH,MU,MXIM,NFLX,NTES,NVDA,NXPI,OKTA,ORLY,PAYX,PCAR,PDD,PEP,PTON,PYPL,QCOM,REGN,ROST,SBUX,SGEN,SIRI,SNPS,SPLK,SWKS,TCOM,TEAM,TMUS,TSLA,TXN,VRSK,VRSN,VRTX,WBA,WDAY,XEL,XLNX,ZM&r={page}', headers = headers).text


    tables = pd.read_html(screen)
    tables = tables[-2]
    tables.columns = tables.iloc[0]
    tables = tables[1:]
    
    return tables

# %%
qqq1 = get_screener('0')
qqq2 = get_screener('21')
qqq3 = get_screener('41')
qqq4 = get_screener('61')
qqq5 = get_screener('81')
qqq6 = get_screener('101')

# %%
qqq = pd.DataFrame()

qqq = pd.concat([qqq1, qqq2, qqq3, qqq4, qqq5, qqq6], axis=0)
qqq = qqq.dropna()
qqq
# Out:
# 0   No. Ticker Perf Week Perf Month Perf Quart Perf Half Perf Year Perf YTD  \
# 1     1   AAPL     1.24%     -0.17%     19.14%    10.18%    31.75%   12.21%
# 2     2   ADBE     0.36%      4.19%     33.78%    27.73%    42.44%   26.84%
# 3     3    ADI    -0.79%      1.46%     14.97%     6.16%    41.40%   14.11%
# 4     4    ADP     0.75%      5.09%     11.62%    28.84%    53.96%   21.96%
# 5     5   ADSK     0.98%     11.76%     23.11%    10.61%    43.39%    8.75%
# ..  ...    ...       ...        ...        ...       ...       ...      ...
# 18   98    WBA     5.09%      5.20%     -8.90%    -1.60%    17.93%   23.67%
# 19   99   WDAY    -0.28%      1.42%      5.73%   -14.73%    32.02%   -1.79%
# 20  100    XEL    -0.65%      1.03%     -3.28%    11.73%    -3.76%    3.18%
# 1   101   XLNX    -3.33%      9.95%     27.34%     1.21%    37.64%    2.95%
# 2   102     ZM    -8.98%      0.62%     25.06%   -16.15%    53.29%    7.57%
#
# ...

# %%
qqq.to_csv(r'C:\Users\Luke\Desktop\Personal\qqq.csv')

# %%
qq = pd.DataFrame()

qq['Perf Month'] = qqq['Perf Month']
qq['Perf Quart'] = qqq['Perf Quart']
qq['Perf Half'] = qqq['Perf Half']
qq['Perf Year'] = qqq['Perf Year']
qq
# Out:
#    Perf Month Perf Quart Perf Half Perf Year
# 1      -0.17%     19.14%    10.18%    31.75%
# 2       4.19%     33.78%    27.73%    42.44%
# 3       1.46%     14.97%     6.16%    41.40%
# 4       5.09%     11.62%    28.84%    53.96%
# 5      11.76%     23.11%    10.61%    43.39%
# ..        ...        ...       ...       ...
# 18      5.20%     -8.90%    -1.60%    17.93%
# 19      1.42%      5.73%   -14.73%    32.02%
# 20      1.03%     -3.28%    11.73%    -3.76%
# 1       9.95%     27.34%     1.21%    37.64%
# 2       0.62%     25.06%   -16.15%    53.29%
#
# [102 rows x 4 columns]

# %%
qq.to_csv(r'C:\Users\Luke\Desktop\Personal\qqq.csv')

# %%
q = pd.read_csv(r'C:\Users\Luke\Desktop\Personal\qqq1.csv')
q['Comp Score'] = q.mean(axis=1)
# Out:
#      Perf Month  Perf Quart  Perf Half  Perf Year  Comp Score
# 0          0.00        0.19       0.10       0.32      0.1525
# 1          0.04        0.34       0.28       0.42      0.2700
# 2          0.01        0.15       0.06       0.41      0.1575
# 3          0.05        0.12       0.29       0.54      0.2500
# 4          0.12        0.23       0.11       0.43      0.2225
# ..          ...         ...        ...        ...         ...
# 97         0.05       -0.09      -0.02       0.18      0.0300
# 98         0.01        0.06      -0.15       0.32      0.0600
# 99         0.01       -0.03       0.12      -0.04      0.0150
# 100        0.10        0.27       0.01       0.38      0.1900
# 101        0.01        0.25      -0.16       0.53      0.1575
#
# [102 rows x 5 columns]

# %%
q.to_csv((r'C:\Users\Luke\Desktop\Personal\Nas.csv'))

# %%
# Performance is v141

headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'}
   
def get_screener(page):
    screen = requests.get(f'https://finviz.com/screener.ashx?v=121&ft=4&t=MRNA,TEAM,ALGN,ASML,TSLA,NVDA,INTU,GOOG,DOCU,IDXX,MRVL,CDW,MELI,AMAT', headers = headers).text


    tables = pd.read_html(screen)
    tables = tables[-2]
    tables.columns = tables.iloc[0]
    tables = tables[1:]
    
    return tables

# %%
sheep = get_screener('0')
sheep
# Out:
# 0  No. Ticker Market Cap     P/E Fwd P/E   PEG    P/S      P/B     P/C  \
# 1    1   ALGN     56.18B   80.26   52.79  2.52  16.17    16.44       -
# 2    2   AMAT    117.79B   26.93   17.59  1.08   5.94     9.89   17.41
# 3    3   ASML    332.99B   57.46   39.34  1.93  16.96    22.46   52.38
# 4    4    CDW     27.83B   30.28   23.85  2.38   1.41    26.39   55.53
# 5    5   DOCU     58.15B       -  134.52     -  35.78   236.43   74.48
# 6    6   GOOG   1899.99B   36.88   29.15  1.76   9.66     8.08       -
# 7    7   IDXX     59.21B   80.59   72.28  4.68  19.43    77.13  255.10
# 8    8   INTU    147.74B   68.75   49.59  4.33  16.62    14.72   35.89
# 9    9   MELI     93.42B       -  400.41     -  16.91  1130.47   47.46
# 10  10   MRNA    158.13B   48.86   18.27  2.91  22.53    40.77   20.44
# 11  11   MRVL     49.47B       -   32.27     -  15.92     2.79   94.68
# 12  12   NVDA    502.63B   94.38   46.01  3.61  26.10    26.33   39.27
# ...

# %%
qqq_f = pd.DataFrame()

qqq_f['Ticker'] = sheep['Ticker']
qqq_f['P/E'] = sheep['P/E']
qqq_f['Fwd P/E'] = sheep['Fwd P/E']
qqq_f.to_csv((r'C:\Users\Luke\Desktop\Personal\qqq_f.csv'))

# %%
qqq_v = pd.DataFrame()

qqq_v['Ticker'] = sheep['Ticker']
qqq_v['EPS this Y'] = sheep['EPS this Y']
qqq_v['EPS next Y'] = sheep['EPS next Y']
qqq_v['EPS next 5Y'] = sheep['EPS next 5Y']
qqq_v['EPS past 5Y'] = sheep['EPS past 5Y']
qqq_v.to_csv((r'C:\Users\Luke\Desktop\Personal\qqq_v.csv'))

# %%
qqq_vv = pd.read_csv(r'C:\Users\Luke\Desktop\Personal\qqq_vv.csv')
qqq_vv.dtypes
# Out:
# Ticker          object
# EPS this Y     float64
# EPS next Y     float64
# EPS next 5Y    float64
# EPS past 5Y    float64
# dtype: object

# %%
qqq_vv['Comp EPS'] = qqq_vv.mean(axis=1)
qqq_vv.to_csv(r'C:\Users\Luke\Desktop\Personal\qqq_vvv.csv')
